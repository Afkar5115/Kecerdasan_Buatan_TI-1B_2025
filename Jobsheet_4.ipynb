# %% [markdown]
# <a href="https://colab.research.google.com/github/Afkar5115/Kecerdasan_Buatan_TI-1B_2025/blob/main/Jobsheet_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # JOBSHEET 4 : PENGOLAHAN DATA MENGGUNAKAN PANDAS

# %% [markdown]
# ## Latihan

# %% [markdown]
# ###  1.Membaca berbagai format file menggunakan Pandas

# %% [markdown]
# #### a.	Membaca file CSV

# %%
import pandas as pd

df = pd.read_csv('./data.csv')
print(df.to_string())

pd
pd.options.display.max_rows

pd.options.display.max_rows = 9999

df = pd.read_csv('./data.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# #### b.	Membaca file JSON

# %%
import pandas as pd

df = pd.read_json('./data.json')
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# #### c.	Menggunakan Parameter pada Pandas Read

# %%
df = pd.read_csv('./data.csv', sep=',', header=0)
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# #### d.	Membaca Custom Data

# %%
data = {
  "Duration": {
    "0": 60,
    "1": 60,
    "2": 60,
    "3": 45
  },
  "Pulse": {
    "0": 110,
    "1": 117,
    "2": 103,
    "3": 109
  },
  "Maxpulse": {
    "0": 130,
    "1": 145,
    "2": 135,
    "3": 175
  },
  "Calories": {
    "0": 409,
    "1": 479,
    "2": 340,
    "3": 282
  }
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282

# %% [markdown]
# ### 2.Membuat dan Mengakses Elemen Series

# %% [markdown]
# #### a.	Membuat Series dari sebuah List Python

# %%
import pandas as pd

li = [1, 7, 2]
se = pd.Series(li)

print(se)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %% [markdown]
# #### b.	Mengakses Elemen pada Series

# %%
li = [1, 7, 2]
se = pd.Series(li)

print(se[0])
# Out:
# 1

# %% [markdown]
# #### c.	Memberi Label pada Series

# %%
li = [1, 7, 2]
se = pd.Series(li, index = ['x', 'y', 'z'])

print(se['x'])
# Out:
# 1

# %% [markdown]
# #### d.	Membuat Series dari Dictionary

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}
se = pd.Series(calories)

print(se)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# ### 3.Membuat DataFrame

# %% [markdown]
# #### a.	Membuat DataFrame

# %%
import pandas as pd

df = pd.DataFrame(data= {"Nama" : ["Ali","Joko","Adi"],
	                       "Umur": [12, 13, 15],
	                       "Kelas": [6, 7, 8]})
df.columns
df.columns.values[0] = "Nama Singkat"
df

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %% [markdown]
# #### b.	Mengakses Elemen pada DataFrame

# %%
df.iloc[0:2, [0,1]]
df.iloc[0:2, 0:2]
df.iloc[:, 0:2]
df.loc[0:2, :'calories']
df.loc[0:2, ['calories', 'duration']]
df['calories']
df['calories'][0]
df[['calories']]
df[['calories']].loc[[0, 1]]
# Out:
#    calories
# 0       420
# 1       380

# %% [markdown]
# #### c.	Memberi Nama pada Index

# %%
data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

df = pd.DataFrame(data, index = ['day1', 'day2', 'day3'])
print(df)
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %% [markdown]
# #### d.	Melihat DataFrame

# %%
df = pd.read_csv('./data.csv')
print(df)
df
df.head()
df.tail()
df.head(10)
df.shape
df.dtypes
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %% [markdown]
# #### e.	Membaca Informasi pada DataFrame

# %%
df.info()
df.describe()
df['Calories'].mean(), df['Calories'].median(), df['Calories'].mode()[0]
df.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %% [markdown]
# ## Praktikum

# %% [markdown]
# ### 1.Load dataset “Top Score English Premier League (EPL) musim 2020/2021” dan ubah menjadi dataframe

# %%
import pandas as pd

# Load dataset dari file CSV
df = pd.read_csv("epl-goalScorer(20-21).csv")

# Tampilkan beberapa baris pertama
print(df.head())
# Out:
#    Unnamed: 0    id      player_name  games  time  goals         xG  assists  \
# 0           0   647       Harry Kane     35  3097     23  22.174859       14
# 1           1  1250    Mohamed Salah     37  3085     22  20.250847        5
# 2           2  1228  Bruno Fernandes     37  3117     18  16.019454       12
# 3           3   453    Son Heung-Min     37  3139     17  11.023287       10
# 4           4   822  Patrick Bamford     38  3085     17  18.401863        7
#
#           xA  shots  key_passes  yellow_cards  red_cards position  \
# 0   7.577094    138          49             1          0        F
# 1   6.528526    126          55             0          0    F M S
# 2  11.474996    121          95             6          0      M S
# 3   9.512992     68          75             0          0    F M S
# 4   3.782247    107          30             3          0      F S
#
#           team_title  npg       npxG    xGChain  xGBuildup
# ...

# %% [markdown]
# ### 2.Ambil 5 data pertama dari dataset “Top Score English Premier League (EPL) musim 2020/2021”

# %%
import pandas as pd

# Membaca dataset
data = pd.read_csv('epl-goalScorer(20-21).csv')

# Memilih kolom yang ingin ditampilkan
selected_columns = [
    'player_name', 'goals', 'assists', 'team_title', 'position', 'games', 'shots', 'yellow_cards', 'red_cards'
]

# Mengambil 5 data pertama dengan kolom yang dipilih
top_5 = data[selected_columns].head(5)

# Mengatur tampilan pandas agar lebih lebar
pd.set_option('display.max_columns', None)  # Menampilkan semua kolom
pd.set_option('display.width', 1000)       # Lebar tampilan
pd.set_option('display.colheader_justify', 'left')  # Rata kiri header

# Menampilkan hasil
print("Top 5 Pencetak Gol EPL 2020/2021:")
print(top_5.to_string(index=False))  # Menghilangkan indeks default
# Out:
# Top 5 Pencetak Gol EPL 2020/2021:
# player_name      goals  assists team_title        position  games  shots  yellow_cards  red_cards
#      Harry Kane 23     14               Tottenham     F    35     138    1             0
#   Mohamed Salah 22      5               Liverpool F M S    37     126    0             0
# Bruno Fernandes 18     12       Manchester United   M S    37     121    6             0
#   Son Heung-Min 17     10               Tottenham F M S    37      68    0             0
# Patrick Bamford 17      7                   Leeds   F S    38     107    3             0

# %% [markdown]
# ### 3.Tampilkan jumlah baris dan jumlah kolom dari dataset

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('epl-goalScorer(20-21).csv')

# Dapatkan jumlah baris dan kolom
rows, cols = df.shape

# Tampilkan hasil
print(" Informasi Dataset EPL 2020/2021")
print(f" Jumlah Baris (Data) : {rows}")
print(f" Jumlah Kolom (Fitur): {cols}")
# Out:
#  Informasi Dataset EPL 2020/2021
#  Jumlah Baris (Data) : 522
#  Jumlah Kolom (Fitur): 19

# %% [markdown]
# ### 4.Tampilkan tipe data dari masing-masing kolom dataset

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('epl-goalScorer(20-21).csv')

# Tampilkan tipe data dari setiap kolom
print(" Tipe Data Setiap Kolom:")
print(df.dtypes)
# Out:
#  Tipe Data Setiap Kolom:
# Unnamed: 0        int64
# id                int64
# player_name      object
# games             int64
# time              int64
# goals             int64
# xG              float64
# assists           int64
# xA              float64
# shots             int64
# key_passes        int64
# yellow_cards      int64
# red_cards         int64
# position         object
# team_title       object
# npg               int64
# npxG            float64
# xGChain         float64
# xGBuildup       float64
# dtype: object

# %% [markdown]
# ### 5.Tampilkan jumlah goal yang dicetak setiap pemain yang terdapat di dataset

# %%
import pandas as pd

# Membaca file CSV
df = pd.read_csv('epl-goalScorer(20-21).csv')

# Menampilkan kolom 'player_name' dan 'goals' saja
goal_scorers = df[['player_name', 'goals']]

# Mengurutkan berdasarkan jumlah goal secara descending
goal_scorers_sorted = goal_scorers.sort_values(by='goals', ascending=False)

# Menampilkan hasil
print("Daftar Jumlah Goal Setiap Pemain:")
print(goal_scorers_sorted.to_string(index=False))
# Out:
# Daftar Jumlah Goal Setiap Pemain:
#               player_name  goals
#                Harry Kane     23
#             Mohamed Salah     22
#           Bruno Fernandes     18
#           Patrick Bamford     17
#             Son Heung-Min     17
#     Dominic Calvert-Lewin     16
#               Jamie Vardy     15
#             Ollie Watkins     14
#       Alexandre Lacazette     13
#            Ilkay Gündogan     13
#                Danny Ings     12
#                Chris Wood     12
#             Callum Wilson     12
#         Kelechi Iheanacho     12
#               Gareth Bale     11
#             Wilfried Zaha     11
#           Marcus Rashford     11
#           Matheus Pereira     11
#                Sadio Mané     11
#              Tomas Soucek     10
#         Christian Benteke     10
#            Anwar El Ghazi     10
#            Edinson Cavani     10
#           Michail Antonio     10
#           Raheem Sterling     10
# Pierre-Emerick Aubameyang     10
# ...

# %% [markdown]
# ### 6.Tampilkan dataframe yang hanya terdiri dari nama pemain, goal, posisi, nama klub pemain, dan jumlah kartu kuning

# %%
import pandas as pd

# Membaca file CSV (pastikan file sudah diupload ke Google Colab)
df = pd.read_csv('epl-goalScorer(20-21).csv')

# Memilih dan mengatur urutan kolom
result_df = df[['player_name', 'goals', 'position', 'team_title', 'yellow_cards']]

# Menampilkan dataframe dengan gaya agar lebih mudah dibaca
from IPython.display import display
display(result_df)
# Out:
#                    player_name  goals position                     team_title  \
# 0                   Harry Kane     23        F                      Tottenham
# 1                Mohamed Salah     22    F M S                      Liverpool
# 2              Bruno Fernandes     18      M S              Manchester United
# 3                Son Heung-Min     17    F M S                      Tottenham
# 4              Patrick Bamford     17      F S                          Leeds
# 5        Dominic Calvert-Lewin     16      F S                        Everton
# 6                  Jamie Vardy     15      F S                      Leicester
# 7                Ollie Watkins     14        F                    Aston Villa
# 8               Ilkay Gündogan     13      M S                Manchester City
# 9          Alexandre Lacazette     13    F M S                        Arsenal
# 10               Callum Wilson     12      F S               Newcastle United
# ...

# %% [markdown]
# ### 7.Tampilkan semua pemain dari klub “Liverpool”

# %%
import pandas as pd

# Membaca file CSV
df = pd.read_csv('epl-goalScorer(20-21).csv')

# Filter pemain dari Liverpool
liverpool_players = df[df['team_title'] == 'Liverpool']

# Menampilkan kolom yang diinginkan (nama pemain dan informasi tambahan)
result = liverpool_players[['player_name', 'position', 'games', 'goals', 'assists']]

# Mengurutkan berdasarkan nama pemain
result_sorted = result.sort_values(by='player_name')

# Menampilkan hasil
print("Daftar Pemain Liverpool:")
print(result_sorted.to_string(index=False))
# Out:
# Daftar Pemain Liverpool:
#             player_name position  games  goals  assists
#                  Adrián       GK      3      0        0
# Alex Oxlade-Chamberlain    F M S     13      1        1
#                 Alisson       GK     33      1        0
#        Andrew Robertson        D     38      1        7
#       Caoimhin Kelleher       GK      2      0        0
#            Curtis Jones      M S     24      1        2
#              Diogo Jota    F M S     19      9        0
#            Divock Origi      F S      9      0        0
#                 Fabinho    D M S     30      0        0
#     Georginio Wijnaldum      M S     38      2        0
#            James Milner    D M S     26      0        1
#              Joel Matip      D S     10      1        2
#        Jordan Henderson    D M S     21      1        1
#            Joseph Gomez      D S      7      0        0
#   Konstantinos Tsimikas        S      2      0        0
# ...

# %% [markdown]
# ### 8.Tampilkan semua pemain dari klub “Arsenal”

# %%
import pandas as pd

# Membaca file CSV
df = pd.read_csv('epl-goalScorer(20-21).csv')

# Filter pemain dari Arsenal
arsenal_players = df[df['team_title'] == 'Arsenal']

# Menampilkan kolom yang diinginkan (nama pemain dan informasi tambahan)
result = arsenal_players[['player_name', 'position', 'games', 'goals', 'assists']]

# Mengurutkan berdasarkan nama pemain
result_sorted = result.sort_values(by='player_name')

# Menampilkan hasil dengan format tabel rapi
print("DAFTAR PEMAIN ARSENAL MUSIM 2020/2021:")

print(result_sorted.to_string(index=False))
# Out:
# DAFTAR PEMAIN ARSENAL MUSIM 2020/2021:
#               player_name position  games  goals  assists
#       Alexandre Lacazette    F M S     30     13        2
#                Bernd Leno       GK     34      0        0
#               Bukayo Saka  D F M S     31      5        3
#            Calum Chambers      D S      9      0        1
#             Cédric Soares      D S     10      0        1
#             Dani Ceballos      M S     25      0        3
#                David Luiz      D S     20      1        0
#             Eddie Nketiah      F S     17      2        1
#          Emile Smith-Rowe      M S     19      2        4
#                   Gabriel      D S     22      2        0
#        Gabriel Martinelli    F M S     13      2        1
#              Granit Xhaka    D M S     30      1        2
#           Héctor Bellerín      D S     25      1        2
#            Kieran Tierney      D S     26      1        3
# ...

# %% [markdown]
# ### 9.Tampilkan 10 pemain yang memiliki jumlah kartu kuning paling banyak di EPL musim 2020/2021

# %%
import pandas as pd

# Membaca dataset
df = pd.read_csv('epl-goalScorer(20-21).csv')

# Mengambil kolom yang diperlukan dan mengurutkan berdasarkan kartu kuning
top_yellow_cards = df[['player_name', 'team_title', 'yellow_cards']] \
    .sort_values(by='yellow_cards', ascending=False) \
    .head(10)  # Ambil 10 teratas

# Format output
print("="*70)
print(f"{'TOP 10 PEMAIN DENGAN KARTU KUNING TERBANYAK (EPL 2020/2021)':^70}")
print("="*70)
print(top_yellow_cards.to_string(index=False))
print("="*70)
# Out:
# ...
#      TOP 10 PEMAIN DENGAN KARTU KUNING TERBANYAK (EPL 2020/2021)
# ...
#           player_name           team_title  yellow_cards
#           John McGinn          Aston Villa            12
#       Conor Gallagher West Bromwich Albion            11
#         Harry Maguire    Manchester United            11
#       Kalvin Phillips                Leeds            10
# Pierre-Emile Højbjerg            Tottenham             9
#      Luka Milivojevic       Crystal Palace             8
#          Isaac Hayden     Newcastle United             8
#         Yves Bissouma             Brighton             8
#        John Lundstram     Sheffield United             8
#          Douglas Luiz          Aston Villa             8
# ...

# %% [markdown]
# ### 10.Tampilkan 10 pemain yang memiliki jumlah kartu merah paling banyak di EPL musim 2020/2021

# %%
import pandas as pd
from tabulate import tabulate

# Membaca dataset
df = pd.read_csv('epl-goalScorer(20-21).csv')

# Mengambil kolom yang diperlukan dan mengurutkan berdasarkan kartu merah
top_red_cards = df[['player_name', 'team_title', 'red_cards']] \
    .sort_values(by='red_cards', ascending=False) \
    .head(10)

# Membersihkan data (hapus pemain dengan 0 kartu merah)
top_red_cards = top_red_cards[top_red_cards['red_cards'] > 0]

# Format output
print("="*70)
print(f"{'TOP 10 PEMAIN DENGAN KARTU MERAH TERBANYAK (EPL 2020/2021)':^70}")
print("="*70)

# Cek apakah ada data kartu merah
if len(top_red_cards) > 0:
    print(tabulate(top_red_cards,
                 headers=['Nama Pemain', 'Klub', 'Kartu Merah'],
                 tablefmt='grid',
                 showindex=False))
else:
    print("Tidak ada pemain yang menerima kartu merah musim ini")

print("="*70)
# Out:
# ...
#       TOP 10 PEMAIN DENGAN KARTU MERAH TERBANYAK (EPL 2020/2021)
# ...
# +---------------------+----------------------+---------------+
# | Nama Pemain         | Klub                 |   Kartu Merah |
# +=====================+======================+===============+
# | Lewis Dunk          | Brighton             |             2 |
# +---------------------+----------------------+---------------+
# | Matthew Cash        | Aston Villa          |             1 |
# +---------------------+----------------------+---------------+
# | Antonee Robinson    | Fulham               |             1 |
# +---------------------+----------------------+---------------+
# | Christian Benteke   | Crystal Palace       |             1 |
# +---------------------+----------------------+---------------+
# | Matheus Pereira     | West Bromwich Albion |             1 |
# +---------------------+----------------------+---------------+
# | Alexandre Jankewitz | Southampton          |             1 |
# ...
